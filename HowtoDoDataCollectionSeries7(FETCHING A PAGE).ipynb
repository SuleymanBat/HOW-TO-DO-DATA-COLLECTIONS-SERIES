# %% [markdown]
# ## FETCHING A PAGE

# %%
import requests
import json
import pandas as pd
import numpy as np

# %%
page = requests.get("https://api.datamuse.com/words?rel_rhy=funny")

# %%
print(type(page))
# Out:
# <class 'requests.models.Response'>

# %%
print(page.text[:200])
# Out:
# <!DOCTYPE html>
# <html>
# <head id="Head1"><title>
#
#             FAQ
#
# </title><meta name="keywords" content="e-tjänster, etjänster, e tjänster, mina sidor, självservice, självbetjäning,

# %%
print(page.url)
# Out:
# https://api.datamuse.com/words?rel_rhy=funny

# %%
x = page.json() # turn page.text into a python object

# %%
print(type(x))
# Out:
# <class 'list'>

# %%
print(x[0]) # first item in the list
# Out:
# {'word': 'money', 'score': 4415, 'numSyllables': 2}

# %%
print(json.dumps(x, indent=2)) #pretty print the results
# Out:
# [
#   {
#     "word": "money",
#     "score": 4415,
#     "numSyllables": 2
#   },
#   {
#     "word": "honey",
#     "score": 1206,
#     "numSyllables": 2
#   },
#   {
#     "word": "sunny",
#     "score": 717,
#     "numSyllables": 2
#   },
#   {
#     "word": "bunny",
#     "score": 702,
#     "numSyllables": 2
#   },
#   {
#     "word": "blini",
#     "score": 613,
#     "numSyllables": 2
#   },
#   {
#     "word": "gunny",
#     "score": 449,
#     "numSyllables": 2
#   },
#   {
#     "word": "tunny",
#     "score": 301,
#     "numSyllables": 2
#   },
#   {
#     "word": "sonny",
#     "score": 286,
#     "numSyllables": 2
#   },
#   {
#     "word": "dunny",
#     "score": 245,
#     "numSyllables": 2
#   },
#   {
#     "word": "runny",
#     "score": 225,
#     "numSyllables": 2
#   },
#   {
#     "word": "thunny",
#     "score": 222,
#     "numSyllables": 2
#   },
#   {
#     "word": "aknee",
#     "score": 179,
#     "numSyllables": 2
#   },
#   {
#     "word": "squinny",
# ...
